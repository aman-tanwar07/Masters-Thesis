# %% [markdown]
# # ▶️ SESSION START
# > Run these cells top to bottom at the beginning of every session.

# %% [markdown]
# ### 1. Mount Google Drive

# %% [markdown]
# ### 2. Navigate to Project

# %% [markdown]
# ### 3. Set Git Credentials

# %% [markdown]
# ### 4. Pull Latest from GitHub

# %% [markdown]
# ### 5. Install Dependencies
# > Skip this cell if packages are already installed from a previous session today.

# %% [markdown]
# ### 6. Load Config & Set Random Seed

# %% [markdown]
# ### 7. Log in to HuggingFace

# %% [markdown]
# ### 8. GPU Check

# %% [markdown]
# ### 9. Session Ready

# %% [markdown]
# ---
# # ⏹️ SESSION END
# > Run these cells when you are done for the day.

# %% [markdown]
# ### 1. Clear All Notebook Outputs

# %% [markdown]
# ### 2. Check What Changed

# %% [markdown]
# ### 3. Commit & Push to GitHub
# > Edit the commit message to describe what you did this session.
