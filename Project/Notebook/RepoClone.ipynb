# %%
from google.colab import drive, userdata

drive.mount('/content/drive')

# Get token from Colab Secrets
token = userdata.get('GITHUB_TOKEN')
username = 'aman-tanwar07'
repo = 'Masters-Thesis'

# %cd /content/drive/MyDrive

# Clone with token embedded in URL
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git thesis
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# Cloning into 'thesis'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 13 (delta 2), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd /content/drive/MyDrive/thesis

# !git config --global user.email "amantanwer9560@email.com"
# !git config --global user.name "Aman Tanwar"

# Re-embed token in remote URL (needs to be done each session)
# !git remote set-url origin https://{username}:{token}@github.com/{username}/{repo}.git
# Out:
# /content/drive/MyDrive/thesis

# %%
# %cd /content/drive/MyDrive/thesis

# Remove the secret from the last commit
# !git rm --cached Project/Notebook/RepoClone.ipynb
# !git commit --amend --no-edit
# Out:
# /content/drive/MyDrive/thesis
# rm 'Project/Notebook/RepoClone.ipynb'
# [main 8e28871] Add initial project structure
#  Date: Mon Mar 9 13:36:38 2026 +0000
#  1 file changed, 555 insertions(+)
#  create mode 100644 Project/Notebook/00_setup_verification.ipynb

# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

# !git remote set-url origin https://aman-tanwar07:{token}@github.com/aman-tanwar07/Masters-Thesis.git
# !git push --force
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 6.12 KiB | 72.00 KiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/aman-tanwar07/Masters-Thesis.git
#    d280f36..8e28871  main -> main
